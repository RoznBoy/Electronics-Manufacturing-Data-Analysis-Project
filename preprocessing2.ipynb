# %%
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("/Users/rozn/Downloads/전처리된_데이터_220231201.xlsx")

# %%
df
# Out:
#     Exp_ID Cooler_machine       Date Compressor  Start_temp Room_temp  \
# 0       E1           620F 2023-09-11      LG075        28.1        30
# 1       E2           620F 2023-09-11      LG075        21.9        35
# 2       E3           620F 2023-09-12      LG075        27.6        30
# 3       E4           620F 2023-09-12      LG075        27.9        35
# 4       E5           620F 2023-09-13      LG075        28.7        30
# ..     ...            ...        ...        ...         ...       ...
# 161   E162           620R 2023-11-16     BSA057        31.6        35
# 162   E163           620R 2023-11-20     BSA057        28.5        30
# 163   E164           620R 2023-11-22     BSA057        28.9        30
# 164   E165           620R 2023-11-22     BSA057        33.8        35
# 165   E166           620R 2023-11-23     BSA057        31.4        35
#
#           모세관 Cooler_type Cooler_amnt_raw Is_reached_raw Cooling_time_raw  \
# ...

# %%
df.columns
# Out:
# Index(['Exp_ID', 'Cooler_machine', 'Date', 'Compressor', 'Start_temp',
#        'Room_temp', '모세관', 'Cooler_type', 'Cooler_amnt_raw', 'Is_reached_raw',
#        'Cooling_time_raw', 'Low_pressure', 'High_pressure', 'Pipe_diameter',
#        'Pipe_length', 'Cooling_time', 'Is_reached', 'Cooler_amnt'],
#       dtype='object')

# %%
df_F = df[df['Cooler_machine'].str.contains('F')].reset_index(drop=True)
df_R = df[df['Cooler_machine'].str.contains('R')].reset_index(drop=True)

# %%
df_F
# Out:
#    Exp_ID Cooler_machine       Date Compressor  Start_temp Room_temp  \
# 0      E1           620F 2023-09-11      LG075        28.1        30
# 1      E2           620F 2023-09-11      LG075        21.9        35
# 2      E3           620F 2023-09-12      LG075        27.6        30
# 3      E4           620F 2023-09-12      LG075        27.9        35
# 4      E5           620F 2023-09-13      LG075        28.7        30
# 5      E6           620F 2023-09-14      LG075        21.7        35
# 6      E7           620F 2023-09-15      LG075        26.8        30
# 7      E8           620F 2023-09-15      LG075        28.3        30
# 8      E9           620F 2023-09-15      LG075        23.7        35
# 9     E10           620F 2023-09-18      LG075        30.7        30
# 10    E11           620F 2023-09-18      LG075        24.1        35
# 11    E12           620F 2023-09-19      LG075        28.2        30
# 12    E13           620F 2023-09-20      LG075        29.2        30
# ...

# %%
df_R
# Out:
#     Exp_ID Cooler_machine       Date Compressor  Start_temp Room_temp  \
# 0      E57           400R 2023-08-16     BMK140        23.6        25
# 1      E58           400R 2023-08-17     BMK140        19.6        25
# 2      E59           400R 2023-08-17     BMK140        21.9     20-35
# 3      E60           400R 2023-08-18     BMK140        12.5        35
# 4      E61           400R 2023-08-22     BMK140        33.6        35
# ..     ...            ...        ...        ...         ...       ...
# 105   E162           620R 2023-11-16     BSA057        31.6        35
# 106   E163           620R 2023-11-20     BSA057        28.5        30
# 107   E164           620R 2023-11-22     BSA057        28.9        30
# 108   E165           620R 2023-11-22     BSA057        33.8        35
# 109   E166           620R 2023-11-23     BSA057        31.4        35
#
#           모세관 Cooler_type Cooler_amnt_raw Is_reached_raw Cooling_time_raw  \
# ...

# %%
df_F.describe()
# Out:
#                                 Date  Start_temp  Pipe_diameter  Pipe_length  \
# count                             56   56.000000           56.0    56.000000
# mean   2023-10-10 19:17:08.571428608   29.326786            2.4     2.550000
# min              2023-09-11 00:00:00   21.700000            2.4     2.100000
# 25%              2023-09-20 18:00:00   28.175000            2.4     2.300000
# 50%              2023-10-10 00:00:00   28.850000            2.4     2.500000
# 75%              2023-11-01 06:00:00   31.225000            2.4     2.900000
# max              2023-11-23 00:00:00   32.800000            2.4     3.100000
# std                              NaN    2.494247            0.0     0.317376
#
#        Cooling_time  Is_reached  Cooler_amnt
# count     52.000000   56.000000    56.000000
# mean     189.653846    0.875000    84.428571
# min      132.000000    0.000000    80.000000
# 25%      157.000000    1.000000    82.250000
# 50%      176.000000    1.000000    85.000000
# ...

# %%
df_R.describe()
# Out:
#                                 Date  Start_temp  Pipe_diameter  Pipe_length  \
# count                            110  110.000000   1.100000e+02   110.000000
# mean   2023-10-07 06:58:54.545454592   28.830909   2.400000e+00     1.554545
# min              2023-08-16 00:00:00    8.300000   2.400000e+00     1.100000
# 25%              2023-09-18 00:00:00   28.100000   2.400000e+00     1.300000
# 50%              2023-10-08 00:00:00   28.800000   2.400000e+00     1.500000
# 75%              2023-11-01 18:00:00   31.150000   2.400000e+00     1.900000
# max              2023-11-23 00:00:00   37.700000   2.400000e+00     2.100000
# std                              NaN    4.100744   8.922433e-16     0.357780
#
#        Cooling_time  Is_reached  Cooler_amnt
# count     93.000000  110.000000   110.000000
# mean     180.150538    0.836364    75.818182
# min       55.000000    0.000000    55.000000
# 25%      112.000000    1.000000    65.000000
# 50%      137.000000    1.000000    80.000000
# ...

# %%
sns.countplot(x='Is_reached', data=df_F)
plt.title('Distribution of Target Temperature Reach in Freezer')
plt.xlabel('Success : 1 / Fail : 0')
plt.ylabel('Count')
plt.show()

# %%
print(df_F['Is_reached'].value_counts())
# Out:
# Is_reached
# 1    49
# 0     7
# Name: count, dtype: int64

# %%
sns.countplot(x='Is_reached', data=df_R)
plt.title('Distribution of Target Temperature Reach in Refrigerator')
plt.xlabel('Success : 1 / Fail : 0')
plt.ylabel('Count')
plt.show()

# %%
print(df_R['Is_reached'].value_counts())
# Out:
# Is_reached
# 1    92
# 0    18
# Name: count, dtype: int64

# %%
# cooler_type에 따라 포인트 색상을 지정하여 scatter plot 생성
sns.scatterplot(x='Cooler_amnt', y='Cooling_time', hue='Room_temp', data=df_R)
plt.title(f'Scatter Plot of cooler_amount')
plt.xlabel('Cooler Amount (g)')
plt.ylabel('Cooling time (min)')
plt.show()

# %%
# cooler_type에 따라 포인트 색상을 지정하여 scatter plot 생성
sns.scatterplot(x='Cooler_amnt', y='Cooling_time', hue='Room_temp', data=df_F, palette='Set1')
plt.title(f'Scatter Plot of cooler_amount')
plt.xlabel('Cooler Amount (g)')
plt.ylabel('Cooling time (min)')
plt.show()

# %%
# Unique한 Pipe_length 값들 가져오기
unique_pipe_lengths = df_F['Pipe_length'].unique()
unique_pipe_lengths = sorted(unique_pipe_lengths)
unique_pipe_lengths
# Out:
# [2.1, 2.3, 2.5, 2.7, 2.9, 3.1]

# %%
for i in unique_pipe_lengths:
    print(i)
    filtered_df = df_F[df_F['Pipe_length'] == i]

    # Cooler_amnt을 x 축, Cooling_time을 y 축으로 하는 산점도(Scatter plot) 그리기
    sns.scatterplot(x='Cooler_amnt', y='Cooling_time', hue='Room_temp', data=filtered_df)
    plt.title(f'Cooling Time vs Cooler Amount for Pipe Length {i}')
    plt.xlabel('Cooler Amount (g)')
    plt.ylabel('Cooling Time (min)')
    plt.show()
# Out:
# 2.1
# 2.3
# 2.5
# 2.7
# 2.9
# 3.1

# %%
# Unique한 Pipe_length 값들 가져오기
unique_pipe_lengths = df_R['Pipe_length'].unique()
unique_pipe_lengths = sorted(unique_pipe_lengths)
unique_pipe_lengths
# Out:
# [1.1, 1.3, 1.4, 1.5, 1.6, 1.7, 1.9, 2.1]

# %%
for i in unique_pipe_lengths:
    print(i)
    filtered_df = df_R[df_R['Pipe_length'] == i]

    # Cooler_amnt을 x 축, Cooling_time을 y 축으로 하는 산점도(Scatter plot) 그리기
    sns.scatterplot(x='Cooler_amnt', y='Cooling_time', hue='Room_temp', data=filtered_df)
    plt.title(f'Cooling Time vs Cooler Amount for Pipe Length {i}')
    plt.xlabel('Cooler Amount (g)')
    plt.ylabel('Cooling Time (min)')
    plt.show()
# Out:
# 2.1
# 2.3
# 2.5
# 2.7
# 2.9
# 3.1

# %%
# # Unique한 Pipe_length 값들 가져오기
# unique_pipe_lengths = df_F['Pipe_length'].unique()
# unique_pipe_lengths = sorted(unique_pipe_lengths)

# # 2x3 subplot 생성
# fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(12, 8))
# fig.suptitle('Cooling Time vs Cooler Amount for Different Pipe Lengths')

# # for문을 사용하여 각각의 그래프 그리기
# for i, pipe_length_value in enumerate(unique_pipe_lengths):
#     # Pipe_length 컬럼이 현재의 값인 행만 선택
#     filtered_df = df_F[df_F['Pipe_length'] == pipe_length_value]

#     # 현재 위치에 산점도(Scatter plot) 그리기
#     row, col = i // 2, i % 2
#     axes[row, col].scatter(filtered_df['Cooler_amnt'], filtered_df['Cooling_time'])
#     axes[row, col].set_title(f'Pipe Length {pipe_length_value}')
#     axes[row, col].set_xlabel('Cooler Amount')
#     axes[row, col].set_ylabel('Cooling Time')

# # 그래프 간 간격 조절
# plt.tight_layout(rect=[0, 0, 1, 0.96])

# # 그래프 보이기
# plt.show()

# %%
# df_RO = df_R[df_R['Is_reached'] == 1]
# # Unique한 Pipe_length 값들 가져오기
# unique_pipe_lengths = df_RO['Pipe_length'].unique()
# unique_pipe_lengths = sorted(unique_pipe_lengths)
# print(unique_pipe_lengths)

# # 2x3 subplot 생성
# fig, axes = plt.subplots(nrows=4, ncols=2, figsize=(12, 8))
# fig.suptitle('Cooling Time vs Cooler Amount for Different Pipe Lengths')

# # for문을 사용하여 각각의 그래프 그리기
# for i, pipe_length_value in enumerate(unique_pipe_lengths):
#     # Pipe_length 컬럼이 현재의 값인 행만 선택
#     filtered_df = df_RO[df_RO['Pipe_length'] == pipe_length_value]

#     # 현재 위치에 산점도(Scatter plot) 그리기
#     row, col = i // 2, i % 2
#     axes[row, col].scatter(filtered_df['Cooler_amnt'], filtered_df['Cooling_time'])
#     axes[row, col].set_title(f'Pipe Length {pipe_length_value}')
#     axes[row, col].set_xlabel('Cooler Amount')
#     axes[row, col].set_ylabel('Cooling Time')

# # 그래프 간 간격 조절
# plt.tight_layout(rect=[0, 0, 1, 0.96])

# # 그래프 보이기
# plt.show()
# Out:
# [1.1, 1.3, 1.4, 1.5, 1.6, 1.7, 1.9, 2.1]

# %%
R600a_F = df_F[df_F['cooler_type'] == 'R600a']
R290_F = df_F[df_F['cooler_type'] == 'R290']
print(R600a_F['is_reached'].value_counts())
print(R290_F['is_reached'].value_counts())
# Out:
# is_reached
# 0    33
# 1    15
# Name: count, dtype: int64
# is_reached
# 1    27
# 0     1
# Name: count, dtype: int64

# %%
# sns.pairplot(df_F)
# plt.suptitle('Pairplot of Freezer', y=1.02)
# plt.show()

# %%
# 고정된 pipe_diameter 값에 대한 Scatter Plot
# fixed_pipe_diameter_value = 2.2  # 원하는 pipe_diameter 값
# subset_df = df_F[df_F['pipe_diameter'] == fixed_pipe_diameter_value]

# print(subset_df['is_reached'].value_counts())

# # cooler_type에 따라 포인트 색상을 지정하여 scatter plot 생성
# sns.scatterplot(x='cooler_amnt', y='min_temp', hue='cooler_type', data=subset_df)
# plt.title(f'Scatter Plot of cooler_amnt vs min_temp (pipe_diameter={fixed_pipe_diameter_value})')
# plt.xlabel('Cooler Amount')
# plt.ylabel('Min Temperature')
# plt.show()
# Out:
# is_reached
# 0    32
# 1    13
# Name: count, dtype: int64

# %%
# 고정된 pipe_diameter 값에 대한 Scatter Plot
fixed_pipe_diameter_value = 2.4  # 원하는 pipe_diameter 값
subset_df = df_F[df_F['pipe_diameter'] == fixed_pipe_diameter_value]

print(subset_df['is_reached'].value_counts())

# cooler_type에 따라 포인트 색상을 지정하여 scatter plot 생성
sns.scatterplot(x='cooler_amnt', y='min_temp', hue='cooler_type', data=subset_df)
plt.title(f'Scatter Plot of cooler_amnt vs min_temp (pipe_diameter={fixed_pipe_diameter_value})')
plt.xlabel('Cooler Amount')
plt.ylabel('Min Temperature')
plt.show()
# Out:
# is_reached
# 1    29
# 0     2
# Name: count, dtype: int64

# %%
fixed_pipe_diameter_value = 2.2  # 원하는 pipe_diameter 값
subset_df = R600a_F[R600a_F['pipe_diameter'] == fixed_pipe_diameter_value]

print(subset_df['is_reached'].value_counts())

fixed_pipe_diameter_value = 2.2  # 원하는 pipe_diameter 값
subset_df = R290_F[R290_F['pipe_diameter'] == fixed_pipe_diameter_value]

print(subset_df['is_reached'].value_counts())
# Out:
# is_reached
# 0    32
# 1    13
# Name: count, dtype: int64
# Series([], Name: count, dtype: int64)

# %%
fixed_pipe_diameter_value = 2.4  # 원하는 pipe_diameter 값
subset_df = R600a_F[R600a_F['pipe_diameter'] == fixed_pipe_diameter_value]

print(subset_df['is_reached'].value_counts())

fixed_pipe_diameter_value = 2.4  # 원하는 pipe_diameter 값
subset_df = R290_F[R290_F['pipe_diameter'] == fixed_pipe_diameter_value]

print(subset_df['is_reached'].value_counts())
# Out:
# is_reached
# 1    2
# 0    1
# Name: count, dtype: int64
# is_reached
# 1    27
# 0     1
# Name: count, dtype: int64

# %%
df_F['pipe_length'].describe()
# Out:
# count    76.000000
# mean      2.806579
# std       0.390670
# min       1.100000
# 25%       2.500000
# 50%       2.950000
# 75%       3.100000
# max       3.300000
# Name: pipe_length, dtype: float64

# %%
# pipe_length 값을 4등분하여 새로운 카테고리형 컬럼 생성
df_F['pipe_length_category'] = pd.cut(df_F['pipe_length'], bins=4)

# scatter plot 생성
sns.scatterplot(x='cooler_amnt', y='min_temp', hue='pipe_length_category', data=df_F)

# 그래프 제목과 라벨 추가
plt.title('Scatter Plot of cooler_amnt vs min_temp by pipe_length category')
plt.xlabel('Cooler Amount')
plt.ylabel('Min Temperature')

# 그래프 표시
plt.show()

# %%
# pipe_length 값을 4등분하여 새로운 카테고리형 컬럼 생성
R600a_F['pipe_length_category'] = pd.cut(R600a_F['pipe_length'], bins=10)

# scatter plot 생성
sns.scatterplot(x='cooler_amnt', y='min_temp', hue='pipe_length_category', data=R600a_F)

# 그래프 제목과 라벨 추가
plt.title('Scatter Plot of cooler_amnt vs min_temp by pipe_length category')
plt.xlabel('Cooler Amount')
plt.ylabel('Min Temperature')

# 그래프 표시
plt.show()
# Out:
# /var/folders/md/m1x09h894955mqbsj7vld39m0000gn/T/ipykernel_74064/2418065755.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   R600a_F['pipe_length_category'] = pd.cut(R600a_F['pipe_length'], bins=10)

# %%
# pipe_length 값을 4등분하여 새로운 카테고리형 컬럼 생성
R290_F['pipe_length_category'] = pd.cut(R290_F['pipe_length'], bins=10)

fixed_pipe_diameter_value = 2.4  # 원하는 pipe_diameter 값
subset_df = R290_F[R290_F['pipe_diameter'] == fixed_pipe_diameter_value]

print(subset_df['is_reached'].value_counts())

# scatter plot 생성
sns.scatterplot(x='cooler_amnt', y='min_temp', hue='pipe_length_category', data=subset_df)

# 그래프 제목과 라벨 추가
plt.title(f'Scatter Plot of cooler_amnt vs min_temp by pipe_length category (pipe_diameter={fixed_pipe_diameter_value})')
plt.xlabel('Cooler Amount')
plt.ylabel('Min Temperature')

# 그래프 표시
plt.show()
# Out:
# is_reached
# 1    27
# 0     1
# Name: count, dtype: int64
# /var/folders/md/m1x09h894955mqbsj7vld39m0000gn/T/ipykernel_74064/1871923788.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   R290_F['pipe_length_category'] = pd.cut(R290_F['pipe_length'], bins=10)

# %%
# pipe_length 값을 4등분하여 새로운 카테고리형 컬럼 생성
R290_F['pipe_length_category'] = pd.cut(R290_F['pipe_length'], bins=10)

fixed_pipe_diameter_value = 2.2  # 원하는 pipe_diameter 값
subset_df = R290_F[R290_F['pipe_diameter'] == fixed_pipe_diameter_value]

print(subset_df['is_reached'].value_counts())

# scatter plot 생성
sns.scatterplot(x='cooler_amnt', y='min_temp', hue='pipe_length_category', data=subset_df)

# 그래프 제목과 라벨 추가
plt.title(f'Scatter Plot of cooler_amnt vs min_temp by pipe_length category (pipe_diameter={fixed_pipe_diameter_value})')
plt.xlabel('Cooler Amount')
plt.ylabel('Min Temperature')

# 그래프 표시
plt.show()
# Out:
# Series([], Name: count, dtype: int64)
# /var/folders/md/m1x09h894955mqbsj7vld39m0000gn/T/ipykernel_74064/2900905896.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   R290_F['pipe_length_category'] = pd.cut(R290_F['pipe_length'], bins=10)

# %%
# cooler_type에 따라 포인트 색상을 지정하여 scatter plot 생성
sns.scatterplot(x='cooler_amnt', y='min_temp', hue='is_reached', data=df_F)
plt.title(f'Scatter Plot of cooler_amnt vs min_temp')
plt.xlabel('Cooler Amount')
plt.ylabel('Min Temperature')
plt.show()

# %%
a = df_R[df_R['min_temp'] <= -5] 
b = a[a['min_temp'] >= 10]
b
# Out:
# Empty DataFrame
# Columns: [file_name, Date, refrige_info, pipe_diameter, pipe_length, cooler_amnt, min_temp, target_temp, is_reached, cooler_type, mean_room_temp]
# Index: []

# %%
# pipe_length 값을 4등분하여 새로운 카테고리형 컬럼 생성
R290_F['pipe_length_category'] = pd.cut(R290_F['pipe_length'], bins=10)

# scatter plot 생성
sns.scatterplot(x='cooler_amnt', y='min_temp', hue='pipe_length_category', data=R290_F)

# 그래프 제목과 라벨 추가
plt.title('Scatter Plot of cooler_amnt vs min_temp by pipe_length category')
plt.xlabel('Cooler Amount')
plt.ylabel('Min Temperature')

# 그래프 표시
plt.show()
# Out:
# /var/folders/md/m1x09h894955mqbsj7vld39m0000gn/T/ipykernel_74064/3485269061.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   R290_F['pipe_length_category'] = pd.cut(R290_F['pipe_length'], bins=10)

# %%
# 산점도 생성
sns.scatterplot(x='cooler_amnt', y='min_temp', hue='cooler_type', data=df_F)

# 그래프 제목과 라벨 추가
plt.title('Scatter Plot of cooler_amnt vs min_temp')
plt.xlabel('Cooler Amount')
plt.ylabel('Min Temperature')

# 그래프 표시
plt.show()

# %%
print(df_F['is_reached'].value_counts())
# Out:
# is_reached
# 1    42
# 0    34
# Name: count, dtype: int64

# %%
df_F[df_F['min_temp'] <= -30]
# Out:
#                                 file_name       Date refrige_info  \
# 46  230911_620F_35_2.4_2.7_70-85_EVA.xlsx 2023-09-11         620F
# 47     230911_620F_30_2.4_2.7_85_EVA.xlsx 2023-09-11         620F
# 48     230912_620F_30_2.4_2.7_85_EVA.xlsx 2023-09-12         620F
# 49     230912_620F_35_2.4_2.7_90_EVA.xlsx 2023-09-12         620F
# 50     230913_620F_30_2.4_2.7_80_EVA.xlsx 2023-09-13         620F
# 51     230913_620F_30_2.4_2.7_90_EVA.xlsx 2023-09-13         620F
# 52  230914_620F_35_2.4_2.5_75-80_EVA.xlsx 2023-09-14         620F
# 53     230915_620F_30_2.4_2.5_80_EVA.xlsx 2023-09-15         620F
# 54     230915_620F_35_2.4_2.5_83_EVA.xlsx 2023-09-15         620F
# 55     230918_620F_35_2.4_2.5_85_EVA.xlsx 2023-09-18         620F
# 56     230919_620F_30_2.4_2.5_85_EVA.xlsx 2023-09-19         620F
# 57     230920_620F_35_2.4_2.3_80_EVA.xlsx 2023-09-20         620F
# 58     230921_620F_35_2.4_2.3_85_EVA.xlsx 2023-09-21         620F
# ...

# %%
correlation_matrix = df_F.drop('target_temp', axis=1).corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 correlation_matrix = df_F.drop('target_temp', axis=1).corr()
#       2 sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
#       3 plt.title('Correlation Heatmap')
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# ...

# %% [markdown]
# ###

# %% [markdown]
# # Refrige

# %%
R600a_R = df_R[df_R['cooler_type'] == 'R600a']
R290_R = df_R[df_R['cooler_type'] == 'R290']
print(R600a_R['is_reached'].value_counts())
print(R290_R['is_reached'].value_counts())
# Out:
# 0    18
# 1    16
# Name: is_reached, dtype: int64
# 1    46
# 0     9
# Name: is_reached, dtype: int64

# %%
sns.countplot(x='is_reached', data=df_R)
plt.title('Distribution of is_reached')
plt.xlabel('is_reached')
plt.ylabel('Count')
plt.show()

# %%
# sns.pairplot(df_R)
# plt.suptitle('Pairplot of Refrigerators', y=1.02)
# plt.show()

# %%
# 고정된 pipe_diameter 값에 대한 Scatter Plot
fixed_pipe_diameter_value = 2.4  # 원하는 pipe_diameter 값
subset_df = R290_R[R290_R['pipe_diameter'] == fixed_pipe_diameter_value]

# cooler_type에 따라 포인트 색상을 지정하여 scatter plot 생성
sns.scatterplot(x='cooler_amnt', y='min_temp', hue='cooler_type', data=subset_df)
plt.title(f'Scatter Plot of cooler_amnt vs min_temp (pipe_diameter={fixed_pipe_diameter_value})')
plt.xlabel('Cooler Amount')
plt.ylabel('Min Temperature')
plt.show()

# %%
# 고정된 pipe_diameter 값에 대한 Scatter Plot
fixed_pipe_diameter_value = 2.4  # 원하는 pipe_diameter 값
subset_df = df_R[df_R['pipe_diameter'] == fixed_pipe_diameter_value]

# cooler_type에 따라 포인트 색상을 지정하여 scatter plot 생성
sns.scatterplot(x='cooler_amnt', y='min_temp', hue='cooler_type', data=subset_df)
plt.title(f'Scatter Plot of cooler_amnt vs min_temp (pipe_diameter={fixed_pipe_diameter_value})')
plt.xlabel('Cooler Amount')
plt.ylabel('Min Temperature')
plt.show()

# %%
# 고정된 pipe_diameter 값에 대한 Scatter Plot
fixed_pipe_diameter_value = 2.4  # 원하는 pipe_diameter 값
subset_df = df_R[df_R['pipe_diameter'] == fixed_pipe_diameter_value]

# cooler_type에 따라 포인트 색상을 지정하여 scatter plot 생성
sns.scatterplot(x='cooler_amnt', y='min_temp', hue='is_reached', data=subset_df)
plt.title(f'Scatter Plot of cooler_amnt vs min_temp (pipe_diameter={fixed_pipe_diameter_value})')
plt.xlabel('Cooler Amount')
plt.ylabel('Min Temperature')
plt.show()

# %%
# 고정된 pipe_diameter 값에 대한 Scatter Plot
fixed_pipe_diameter_value = 2.4  # 원하는 pipe_diameter 값
subset_df = df_R[df_R['pipe_diameter'] == fixed_pipe_diameter_value]
subset_df =  subset_df[subset_df['pipe_length'] <= 1.35]
# cooler_type에 따라 포인트 색상을 지정하여 scatter plot 생성
sns.scatterplot(x='cooler_amnt', y='min_temp', hue='cooler_type', data=subset_df)
plt.title(f'Scatter Plot of cooler_amnt vs min_temp (pipe_diameter={fixed_pipe_diameter_value})')
plt.xlabel('Cooler Amount')
plt.ylabel('Min Temperature')
plt.show()

# %%
R600a_R[R600a_R['min_temp'] < -5]
# Out:
#                           file_name       Date refrige_info  pipe_diameter  \
# 2   230817_400R_35_2.4_1.4_100.xlsx 2023-08-17         400R            2.4
# 3    230818_400R_35_2.4_1.4_70.xlsx 2023-08-18         400R            2.4
# 58   230824_620R_35_2.4_1.7_75.xlsx 2023-08-24         620R            2.4
# 59   230901_620R_30_2.4_1.7_80.xlsx 2023-09-01         620R            2.4
# 60   230904_620R_30_2.4_1.7_80.xlsx 2023-09-04         620R            2.4
#
#     pipe_length  cooler_amnt  min_temp  target_temp  is_reached cooler_type  \
# 2           1.4          100 -6.886667            0           1       R600a
# 3           1.4           70 -9.193333            0           1       R600a
# 58          1.7           75 -6.240000            0           1       R600a
# 59          1.7           80 -6.213333            0           1       R600a
# 60          1.7           80 -6.426667            0           1       R600a
#
#     mean_room_temp
# 2        28.262001
# ...

# %%
# pipe_length 값을 4등분하여 새로운 카테고리형 컬럼 생성
df_R['pipe_length_category'] = pd.cut(df_R['pipe_length'], bins=4)

# scatter plot 생성
sns.scatterplot(x='cooler_amnt', y='min_temp', hue='pipe_length_category', data=df_R)

# 그래프 제목과 라벨 추가
plt.title('Scatter Plot of cooler_amnt vs min_temp by pipe_length category')
plt.xlabel('Cooler Amount')
plt.ylabel('Min Temperature')

# 그래프 표시
plt.show()

# %%
# pipe_length 값을 4등분하여 새로운 카테고리형 컬럼 생성
R290_R['pipe_length_category'] = pd.cut(R290_R['pipe_length'], bins=4)

# scatter plot 생성
sns.scatterplot(x='cooler_amnt', y='min_temp', hue='pipe_length_category', data=R290_R)

# 그래프 제목과 라벨 추가
plt.title('Scatter Plot of cooler_amnt vs min_temp by pipe_length category')
plt.xlabel('Cooler Amount')
plt.ylabel('Min Temperature')

# 그래프 표시
plt.show()
# Out:
# <ipython-input-37-40ea0649c1fd>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   R290_R['pipe_length_category'] = pd.cut(R290_R['pipe_length'], bins=4)

# %%
# 산점도 생성
sns.scatterplot(x='cooler_amnt', y='min_temp', hue='cooler_type', data=df_R)

# 그래프 제목과 라벨 추가
plt.title('Scatter Plot of cooler_amnt vs min_temp')
plt.xlabel('Cooler Amount')
plt.ylabel('Min Temperature')

# 그래프 표시
plt.show()

# %%
correlation_matrix = df_R.drop('target_temp', axis=1).corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()
